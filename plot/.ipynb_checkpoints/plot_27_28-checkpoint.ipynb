# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1024 = pd.read_csv('query28/1024.csv')
df2048 = pd.read_csv('query28/2048.csv')
plt.plot(df1024['N'], df1024['runtime'], label='Hash Table Size = 1024')
plt.plot(df2048['N'], df2048['runtime'], label='Hash Table Size = 2048')
plt.legend()
plt.xlabel("N - the number of probings")
plt.ylabel("Query Runtime (ms)")
plt.title("The Query28 Runtime with different N (hash table probing times)")
plt.rcParams['figure.figsize'] = [50, 8]
plt.show()

# %%
df1024 = pd.read_csv('query28/1024final.csv') # IN SCREEN
df2048 = pd.read_csv('query28/2048final.csv') # IN SCREEN
plt.plot(df1024['N'], df1024['cp_times'], label='Hash Table Size = 1024')
plt.plot(df2048['N'], df2048['cp_times'], label='Hash Table Size = 2048')
plt.legend()
plt.xlabel("N - the number of probings")
plt.ylabel("Query Runtime (ms)")
plt.title("The Query28 Runtime with different N (hash table probing times)")
plt.rcParams['figure.figsize'] = [50, 8]
plt.show()

# %%
df1024 = pd.read_csv('query27/1024.csv')
df2048 = pd.read_csv('query27/2048.csv')
plt.plot(df1024['N'], df1024['runtime'], label='Hash Table Size = 1024')
plt.plot(df2048['N'], df2048['runtime'], label='Hash Table Size = 2048')

plt.legend()
plt.xlabel("N - the number of probings")
plt.ylabel("Query Runtime (ms)")
plt.title("The Query27 Runtime with different N (hash table probing times)")
plt.rcParams['figure.figsize'] = [50, 8]
plt.show()

# %%
df1024 = pd.read_csv('query27/1024new.csv')
df2048 = pd.read_csv('query27/2048new.csv')
plt.plot(df1024['N'], df1024['cp_times'], label='Hash Table Size = 1024')
plt.plot(df2048['N'], df2048['cp_times'], label='Hash Table Size = 2048')

plt.legend()
plt.xlabel("N - the number of probings")
plt.ylabel("Query Runtime (ms)")
plt.title("The Query27 Copy Times with different N (hash table probing times)")
plt.rcParams['figure.figsize'] = [50, 8]
plt.show()
